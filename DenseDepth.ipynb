# %% [markdown]
# <a href="https://colab.research.google.com/github/pc-sharma/ssss/blob/main/DenseDepth.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/ialhashim/DenseDepth.git
# Out:
# Cloning into 'DenseDepth'...
# remote: Enumerating objects: 305, done.
# remote: Counting objects: 100% (7/7), done.
# remote: Compressing objects: 100% (5/5), done.
# remote: Total 305 (delta 2), reused 6 (delta 2), pack-reused 298
# Receiving objects: 100% (305/305), 12.15 MiB | 34.26 MiB/s, done.
# Resolving deltas: 100% (152/152), done.

# %%
# !wget https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5 -O ./DenseDepth/nyu.h5
# Out:
# --2023-08-28 03:52:58--  https://s3-eu-west-1.amazonaws.com/densedepth/nyu.h5
# Resolving s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)... 52.92.19.192, 52.218.36.82, 52.92.20.120, ...
# Connecting to s3-eu-west-1.amazonaws.com (s3-eu-west-1.amazonaws.com)|52.92.19.192|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 172897376 (165M) [application/h5]
# Saving to: ‘./DenseDepth/nyu.h5’
#
# ./DenseDepth/nyu.h5 100%[===================>] 164.89M  28.7MB/s    in 6.4s
#
# 2023-08-28 03:53:05 (25.8 MB/s) - ‘./DenseDepth/nyu.h5’ saved [172897376/172897376]

# %%
# !cd DenseDepth; python test.py
# Out:
# Loading model...
#
# Model loaded (nyu.h5).
#
# Loaded (12) images of size (480, 640, 3).
# 6/6 [==============================] - 17s 106ms/step
# /content/DenseDepth/utils.py:77: FutureWarning: `multichannel` is a deprecated argument name for `montage`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   return skimage.util.montage(all_images, multichannel=True, fill=(0,0,0))
# Figure(1000x500)

# %%
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('./DenseDepth/13.jpg') )
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-1-cbcc407e9863> in <cell line: 5>()
#       3
#       4 plt.figure(figsize=(20,20))
# ----> 5 plt.imshow( io.imread('./DenseDepth/12.jpg') )
#
# /usr/local/lib/python3.10/dist-packages/skimage/io/_io.py in imread(fname, as_gray, plugin, **plugin_args)
#      51
#      52     with file_or_url_context(fname) as fname:
# ---> 53         img = call_plugin('imread', fname, plugin=plugin, **plugin_args)
#      54
#      55     if not hasattr(img, 'ndim'):
#
# /usr/local/lib/python3.10/dist-packages/skimage/io/manage_plugins.py in call_plugin(kind, *args, **kwargs)
#     205                                (plugin, kind))
#     206
# --> 207     return func(*args, **kwargs)
#     208
#     209
#
# /usr/local/lib/python3.10/dist-packages/skimage/io/_plugins/imageio_plugin.py in imread(*args, **kwargs)
# ...

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %% [markdown]
# # New Section

# %%
# !cd DenseDepth/PyTorch; python test_pytorch.py
from matplotlib import pyplot as plt
from skimage import io

plt.figure(figsize=(20,20))
plt.imshow( io.imread('./DenseDepth/12.jpg') )
# Out:
# python3: can't open file '/content/DenseDepth/PyTorch/test_pytorch.py': [Errno 2] No such file or directory
